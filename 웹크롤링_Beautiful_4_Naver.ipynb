# %% [markdown]
# ## 04.웹크롤링실습_2
# ### Beautiful_4

# %% [markdown]
# **[학습목표]**
# 1. BeautifulSoup을 활용해 NAVER에서 원하는 기사를 크롤링할 수 있다.

# %%
# Naver 에서 특정 키워드로 기사 검색하기

#Step 1. 필요한 모듈 로딩
from selenium import webdriver
from selenium.webdriver.common.by import By
import time

#Step 2. 사용자에게 검색 관련 정보들을 입력 받는다.
#print("*" *70)
#print(" 이 크롤러는 NAVER의 뉴스 수집용 웹크롤러입니다.")
#print("*" *70)

query_txt = input('키워드를 입력하세요: ')
#query_txt = '빅데이터, 소비트렌드'
print("\n")

#Step 3. 크롬 드라이버 설정 및 웹 페이지 열기
chrome_driver = 'c:py_temp/chromedriver'
driver = webdriver.Chrome()

url = 'https://www.naver.com/'
driver.get(url)                  # 접속 명령어
time.sleep(5)                    # 5초 설정(인터넷 환경에 따라)

#Step 4. 자동으로 검색어 입력 후 조회하기
element = driver.find_element(By.ID, 'query')
driver.find_element(By.ID, 'query').click( )
element.send_keys(query_txt)                # 글자를 타이핑하라
element.send_keys("\n")                     # enter키를 쳐라
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-9056ec98a489> in <cell line: 4>()
#       2
#       3 #Step 1. 필요한 모듈 로딩
# ----> 4 from selenium import webdriver
#       5 from selenium.webdriver.common.by import By
#       6 import time
#
# ModuleNotFoundError: No module named 'selenium'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ## 굿럭!!!
